# %% [markdown]
# pip install tabula-py

# %%
import tabula

# %%
lista_tabelas = tabula.read_pdf('Vale_IFRS_1T21_BRL_v26042021_vf.pdf',pages="11")
# Out:
# Got stderr: out 15, 2021 10:54:41 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# ADVERTÊNCIA: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# out 15, 2021 10:54:41 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# ADVERTÊNCIA: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'

# %%
print(len(lista_tabelas))
# Out:
# 1

# %%
for tabela in lista_tabelas:
    display(tabela)
# Out:
#          US$ milhões     1T21      %     4T20    %.1     1T20    %.2
# 0  Minerais Ferrosos  608.000   60,3  763.000   52,8  627.000   55,8
# 1     Metais Básicos  359.000   35,6  566.000   39,2  352.000   31,3
# 2             Carvão   29.000    2,9   65.000    4,5   80.000    7,1
# 3   Energia e outros   13.000    1,3   50.000    3,5   65.000    5,8
# 4              Total    1.009  100,0    1.444  100,0    1.124  100,0
#          US$ milhões  1T21      %  4T20    %.1  1T20    %.2
# 0  Minerais Ferrosos    82   53,9    69   47,9    91   62,8
# 1     Metais Básicos    68   44,7    55   38,2    52   35,9
# 2   Energia e outros     2    1,3    20   13,9     2    1,4
# 3              Total   152  100,0   144  100,0   145  100,0

# %%
lista_tabelas_2 = tabula.read_pdf('Vale_IFRS_1T21_BRL_v26042021_vf.pdf',pages="10")
# Out:
# Got stderr: out 15, 2021 11:19:56 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# ADVERTÊNCIA: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# out 15, 2021 11:19:57 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# ADVERTÊNCIA: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'

# %%
display(lista_tabelas_2[0])
# Out:
#                  Indicadores financeiros selecionados Unnamed: 0 Unnamed: 1  \
# 0                                          R$ milhões        NaN        NaN
# 1                                                 NaN       1T21       4T20
# 2                          Receita de vendas, líquida     69.301     78.938
# 3                                   Custos e despesas   (27.359)   (35.434)
# 4                  Despesas relacionadas a Brumadinho      (637)   (25.002)
# 5                               EBIT (LAJIR) ajustado     41.729     18.987
# 6                            Margem EBIT ajustado (%)      60,2%      24,1%
# 7                            EBITDA (LAJIDA) ajustado     45.741     23.492
# 8      Lucro líquido atribuído aos acionistas da Vale     30.564      4.825
# 9                                                 NaN        NaN        NaN
# 10                                                NaN        NaN        NaN
# ...

# %%
tabela = lista_tabelas_2[0]
tabela.columns = tabela.iloc[0]
tabela[[0,1]] = tabela["Variação percentual"].str.split(" ", expand=True)
tabela = tabela[1:9]
tabela = tabela.set_index("R$ milhões")
tabela.columns = tabela.iloc[0]
tabela = tabela[1:]
tabela = tabela.drop("1T21/4T20 1T21/1T20", axis=1)

# %%
print(len(lista_tabelas_2))
# Out:
# 1

# %%
display(tabela)
# Out:
# nan                                                 1T21      4T20      1T20  \
# R$ milhões
# Receita de vendas, líquida                        69.301    78.938    31.251
# Custos e despesas                               (27.359)  (35.434)  (21.619)
# Despesas relacionadas a Brumadinho                 (637)  (25.002)     (708)
# EBIT (LAJIR) ajustado                             41.729    18.987     9.248
# Margem EBIT ajustado (%)                           60,2%     24,1%     29,6%
# EBITDA (LAJIDA) ajustado                          45.741    23.492    12.924
# Lucro líquido atribuído aos acionistas da Vale    30.564     4.825       984
#
# nan                                            1T21/4T20 1T21/1T20 1T21/4T20  \
# R$ milhões
# Receita de vendas, líquida                        -12,2%    121,8%    -12,2%
# Custos e despesas                                 -22,8%     26,6%    -22,8%
# Despesas relacionadas a Brumadinho                -97,5%    -10,0%    -97,5%
# ...

# %%
tabela = lista_tabelas_2[0]
tabela.columns = tabela.iloc[0]
tabela[[0,1]] = tabela["Variação percentual"].str.split(" ", expand=True)
tabela = tabela[1:9]
tabela.set_index("R$ milhões", inplace=True)
tabela.columns = tabela.iloc[0]
tabela = tabela[1:]
tabela.drop("1T21/4T20 1T21/1T20", axis=1, inplace=True)
display(tabela)
# Out:
# nan                                                 1T21      4T20      1T20  \
# R$ milhões
# Receita de vendas, líquida                        69.301    78.938    31.251
# Custos e despesas                               (27.359)  (35.434)  (21.619)
# Despesas relacionadas a Brumadinho                 (637)  (25.002)     (708)
# EBIT (LAJIR) ajustado                             41.729    18.987     9.248
# Margem EBIT ajustado (%)                           60,2%     24,1%     29,6%
# EBITDA (LAJIDA) ajustado                          45.741    23.492    12.924
# Lucro líquido atribuído aos acionistas da Vale    30.564     4.825       984
#
# nan                                            1T21/4T20 1T21/1T20 1T21/4T20  \
# R$ milhões
# Receita de vendas, líquida                        -12,2%    121,8%    -12,2%
# Custos e despesas                                 -22,8%     26,6%    -22,8%
# Despesas relacionadas a Brumadinho                -97,5%    -10,0%    -97,5%
# ...

# %% [markdown]
# ## E se ele não tiver reconhecendo a tabela?
#
# 2 parametros para testar
#
# * lattice
# * guess

# %%
# lattice
lista_df = tabula.read_pdf('Vale_IFRS_1T21_BRL_v26042021_vf.pdf',pages="10", lattice=True)
display(lista_df[0])

print("*" * 10)

# guess
lista_df = tabula.read_pdf('Vale_IFRS_1T21_BRL_v26042021_vf.pdf',pages="10", guess=False)
display(lista_df[0])
# Out:
# Got stderr: out 15, 2021 11:32:00 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# ADVERTÊNCIA: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
#                                         Unnamed: 0  \
# 0                                              NaN
# 1                                              NaN
# 2                                       R$ milhões
# 3                                        $ milhões
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                       Receita de vendas, líquida
# 8                        eceita de vendas, líquida
# 9                                              NaN
# 10                                             NaN
# 11              Despesas relacionadas a Brumadinho
# 12               espesas relacionadas a Brumadinho
# 13                           EBIT (LAJIR) ajustado
# ...
